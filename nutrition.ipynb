# %% [markdown]
# <a href="https://colab.research.google.com/github/junio-firmino/Aprendizado_python/blob/master/nutrition.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# %%
data = '/content/drive/MyDrive/nutrition.csv'

# %%
nutrition = pd.read_csv(data)

# %%
nutrition
# Out:
#       Unnamed: 0  ...    water
# 0              0  ...   8.32 g
# 1              1  ...   3.52 g
# 2              2  ...  92.30 g
# 3              3  ...   8.82 g
# 4              4  ...  66.10 g
# ...          ...  ...      ...
# 8784        8784  ...  72.51 g
# 8785        8785  ...  59.95 g
# 8786        8786  ...  59.80 g
# 8787        8787  ...  73.43 g
# 8788        8788  ...  73.43 g
#
# [8789 rows x 77 columns]

# %%
nutrition.info(memory_usage='deep')
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8789 entries, 0 to 8788
# Data columns (total 77 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   Unnamed: 0                   8789 non-null   int64
#  1   name                         8789 non-null   object
#  2   serving_size                 8789 non-null   object
#  3   calories                     8789 non-null   int64
#  4   total_fat                    8789 non-null   object
#  5   saturated_fat                7199 non-null   object
#  6   cholesterol                  8789 non-null   object
#  7   sodium                       8789 non-null   object
#  8   choline                      8789 non-null   object
#  9   folate                       8789 non-null   object
#  10  folic_acid                   8789 non-null   object
#  11  niacin                       8789 non-null   object
#  12  pantothenic_acid             8789 non-null   object
# ...

# %%
nutrition.head(15)
# Out:
#     Unnamed: 0                   name  ... theobromine    water
# 0            0             Cornstarch  ...     0.00 mg   8.32 g
# 1            1           Nuts, pecans  ...     0.00 mg   3.52 g
# 2            2          Eggplant, raw  ...     0.00 mg  92.30 g
# 3            3         Teff, uncooked  ...           0   8.82 g
# 4            4        Sherbet, orange  ...     0.00 mg  66.10 g
# 5            5       Cauliflower, raw  ...     0.00 mg  92.07 g
# 6            6       Taro leaves, raw  ...     0.00 mg  85.66 g
# 7            7      Lamb, raw, ground  ...     0.00 mg  59.47 g
# 8            8      Cheese, camembert  ...     0.00 mg  51.80 g
# 9            9     Vegetarian fillets  ...     0.00 mg  45.00 g
# 10          10    PACE, Picante Sauce  ...           0  89.90 g
# 11          11    Goji berries, dried  ...           0   7.50 g
# 12          12   Mango nectar, canned  ...     0.00 mg  86.63 g
# 13          13   Crackers, rusk toast  ...           0   5.50 g
# ...

# %%
nutrition.tail(5)
# Out:
#       Unnamed: 0  ...    water
# 8784        8784  ...  72.51 g
# 8785        8785  ...  59.95 g
# 8786        8786  ...  59.80 g
# 8787        8787  ...  73.43 g
# 8788        8788  ...  73.43 g
#
# [5 rows x 77 columns]

# %%
nutrition.describe()
# Out:
#         Unnamed: 0     calories  lucopene
# count  8789.000000  8789.000000    8789.0
# mean   4394.000000   226.283878       0.0
# std    2537.310091   169.862001       0.0
# min       0.000000     0.000000       0.0
# 25%    2197.000000    91.000000       0.0
# 50%    4394.000000   191.000000       0.0
# 75%    6591.000000   337.000000       0.0
# max    8788.000000   902.000000       0.0

# %%
nutrition.shape
# Out:
# (8789, 77)

# %%
nutrition_test = {'Unnamed: 0': 'Index'}

# %%
nutrition_test_1 = nutrition.rename(columns=nutrition_test)

# %%
nutrition_test_1
# Out:
#       Index  ...    water
# 0         0  ...   8.32 g
# 1         1  ...   3.52 g
# 2         2  ...  92.30 g
# 3         3  ...   8.82 g
# 4         4  ...  66.10 g
# ...     ...  ...      ...
# 8784   8784  ...  72.51 g
# 8785   8785  ...  59.95 g
# 8786   8786  ...  59.80 g
# 8787   8787  ...  73.43 g
# 8788   8788  ...  73.43 g
#
# [8789 rows x 77 columns]

# %%
nutrition_test_1.drop(columns='Index')
# Out:
#                                                    name  ...    water
# 0                                            Cornstarch  ...   8.32 g
# 1                                          Nuts, pecans  ...   3.52 g
# 2                                         Eggplant, raw  ...  92.30 g
# 3                                        Teff, uncooked  ...   8.82 g
# 4                                       Sherbet, orange  ...  66.10 g
# ...                                                 ...  ...      ...
# 8784  Beef, raw, all grades, trimmed to 0" fat, sepa...  ...  72.51 g
# 8785  Lamb, cooked, separable lean only, composite o...  ...  59.95 g
# 8786  Lamb, raw, separable lean and fat, composite o...  ...  59.80 g
# 8787  Beef, raw, all grades, trimmed to 0" fat, sepa...  ...  73.43 g
# 8788  Beef, raw, all grades, trimmed to 0" fat, sepa...  ...  73.43 g
#
# [8789 rows x 76 columns]

# %%
nutrition_test_1.set_index('Index')
# Out:
#                                                     name  ...    water
# Index                                                     ...
# 0                                             Cornstarch  ...   8.32 g
# 1                                           Nuts, pecans  ...   3.52 g
# 2                                          Eggplant, raw  ...  92.30 g
# 3                                         Teff, uncooked  ...   8.82 g
# 4                                        Sherbet, orange  ...  66.10 g
# ...                                                  ...  ...      ...
# 8784   Beef, raw, all grades, trimmed to 0" fat, sepa...  ...  72.51 g
# 8785   Lamb, cooked, separable lean only, composite o...  ...  59.95 g
# 8786   Lamb, raw, separable lean and fat, composite o...  ...  59.80 g
# 8787   Beef, raw, all grades, trimmed to 0" fat, sepa...  ...  73.43 g
# 8788   Beef, raw, all grades, trimmed to 0" fat, sepa...  ...  73.43 g
#
# [8789 rows x 76 columns]

# %%
nutrition_test_1.sample(frac=0.001)
# Out:
#       Index  ...    water
# 5053   5053  ...  68.90 g
# 5790   5790  ...  83.50 g
# 1441   1441  ...  39.48 g
# 3595   3595  ...  87.90 g
# 977     977  ...  35.99 g
# 3213   3213  ...  71.15 g
# 7267   7267  ...  79.63 g
# 1774   1774  ...  70.24 g
# 1858   1858  ...  81.69 g
#
# [9 rows x 77 columns]

# %%
nutrition.axes[1][5]
# Out:
# 'saturated_fat'

# %%
nutrition_2 = nutrition.set_index('name')

# %%
nutrition_2
# Out:
#                                                     Unnamed: 0  ...    water
# name                                                            ...
# Cornstarch                                                   0  ...   8.32 g
# Nuts, pecans                                                 1  ...   3.52 g
# Eggplant, raw                                                2  ...  92.30 g
# Teff, uncooked                                               3  ...   8.82 g
# Sherbet, orange                                              4  ...  66.10 g
# ...                                                        ...  ...      ...
# Beef, raw, all grades, trimmed to 0" fat, separ...        8784  ...  72.51 g
# Lamb, cooked, separable lean only, composite of...        8785  ...  59.95 g
# Lamb, raw, separable lean and fat, composite of...        8786  ...  59.80 g
# Beef, raw, all grades, trimmed to 0" fat, separ...        8787  ...  73.43 g
# ...

# %%
nutrition_2.loc['Nuts, pecans']['total_fat']
# Out:
# '72g'

# %%
nutrition_2.at['Nuts, pecans','total_fat']
# Out:
# '72g'

# %%
nutrition_2.columns.get_loc('serving_size') # position in the columns
# Out:
# 1

# %%
nutrition_2.head(3)
# Out:
#                Unnamed: 0 serving_size  calories  ... caffeine theobromine    water
# name                                              ...
# Cornstarch              0        100 g       381  ...  0.00 mg     0.00 mg   8.32 g
# Nuts, pecans            1        100 g       691  ...  0.00 mg     0.00 mg   3.52 g
# Eggplant, raw           2        100 g        25  ...  0.00 mg     0.00 mg  92.30 g
#
# [3 rows x 76 columns]

# %%
 nutrition_regex = nutrition.replace('\sg','',regex=True)

# %%
nutrition_regex
# Out:
#       Unnamed: 0  ...  water
# 0              0  ...   8.32
# 1              1  ...   3.52
# 2              2  ...  92.30
# 3              3  ...   8.82
# 4              4  ...  66.10
# ...          ...  ...    ...
# 8784        8784  ...  72.51
# 8785        8785  ...  59.95
# 8786        8786  ...  59.80
# 8787        8787  ...  73.43
# 8788        8788  ...  73.43
#
# [8789 rows x 77 columns]

# %%
nutrition_regex1 = nutrition_regex.serving_size.astype(int)

# %%
nutrition_regex1.head(3)
# Out:
# 0    100
# 1    100
# 2    100
# Name: serving_size, dtype: int64

# %%
nutrition.replace('[a-zA-Z]','',regex=True)
# Out:
#       Unnamed: 0                       name  ... theobromine   water
# 0              0                             ...       0.00    8.32
# 1              1                         ,   ...       0.00    3.52
# 2              2                         ,   ...       0.00   92.30
# 3              3                         ,   ...           0   8.82
# 4              4                         ,   ...       0.00   66.10
# ...          ...                        ...  ...         ...     ...
# 8784        8784  , ,  ,   0" ,    , ,   ,   ...       0.00   72.51
# 8785        8785        , ,   ,     , , ,    ...           0  59.95
# 8786        8786       , ,    ,     , , ,    ...           0  59.80
# 8787        8787  , ,  ,   0" ,   , ,    ,   ...       0.00   73.43
# 8788        8788  , ,  ,   0" ,   , ,    ,   ...       0.00   73.43
#
# [8789 rows x 77 columns]

# %%
nutrition.rename(index={0:'Jo'})
# Out:
#       Unnamed: 0  ...    water
# Jo             0  ...   8.32 g
# 1              1  ...   3.52 g
# 2              2  ...  92.30 g
# 3              3  ...   8.82 g
# 4              4  ...  66.10 g
# ...          ...  ...      ...
# 8784        8784  ...  72.51 g
# 8785        8785  ...  59.95 g
# 8786        8786  ...  59.80 g
# 8787        8787  ...  73.43 g
# 8788        8788  ...  73.43 g
#
# [8789 rows x 77 columns]

# %%
nutrition_chosen = pd.read_csv(data, index_col='serving_size', usecols=['serving_size', 'calories', 'total_fat','sodium','name'],)

# %%
nutrition_chosen
# Out:
#                                                            name  ...    sodium
# serving_size                                                     ...
# 100 g                                                Cornstarch  ...   9.00 mg
# 100 g                                              Nuts, pecans  ...   0.00 mg
# 100 g                                             Eggplant, raw  ...   2.00 mg
# 100 g                                            Teff, uncooked  ...  12.00 mg
# 100 g                                           Sherbet, orange  ...  46.00 mg
# ...                                                         ...  ...       ...
# 100 g         Beef, raw, all grades, trimmed to 0" fat, sepa...  ...  54.00 mg
# 100 g         Lamb, cooked, separable lean only, composite o...  ...  50.00 mg
# 100 g         Lamb, raw, separable lean and fat, composite o...  ...  39.00 mg
# 100 g         Beef, raw, all grades, trimmed to 0" fat, sepa...  ...  53.00 mg
# ...

# %%
len(nutrition.dropna(how='all',axis=0))
# Out:
# 8789

# %%
nutrition.replace('[^a-zA-Z]','',regex=True)

# %%
nutrition_1 = nutrition.drop(columns='Unnamed: 0')

# %%
nutrition_1

# %%
nutrition_1 = nutrition_1.set_index('name')

# %%
nutrition_teste_replace = nutrition_1.replace('[a-zA-Z]','',regex=True)

# %%
nutrition_teste_replace.head(5)

# %%
nutrition_teste_replace.info()

# %%
nutrition_teste_replace.dtypes.value_counts()

# %%
nutrition_teste_replace_all_float = nutrition_teste_replace.astype(float)

# %%
nutrition_teste_replace_all_float.dtypes

# %%
nutrition_teste_replace_all_float.dtypes.value_counts()

# %%
nutrition_teste_replace_all_float.head(10)

# %%
nutrition_teste_replace_all_float.info(verbose=False, memory_usage='deep')

# %%
nutrition_teste_replace_all_float.filter(regex = '[Oo]ctopus', axis=0)

# %%
nutrition_teste_replace_all_float.filter(like = 'Octopus', axis=0)

# %%
nutrition_teste_replace_all_float.filter(items=['sodium', 'niacin', 'riboflavin'], axis=1)\
.filter(items=['Cornstarch', 'Cauliflower, raw','Vegetarian fillets','Cheese, camembert'], axis=0)

# %%
nutrition_teste_replace_all_float.vitamin_b12.head(10)

# %%
nutrition_teste_replace_all_float[nutrition_teste_replace_all_float.calories.between(30,60)]

# %%
len(nutrition_teste_replace_all_float[nutrition_teste_replace_all_float.calories.between(30,60)])

# %%
nutrition_teste_replace_all_float.max(axis=1)

# %%
nutrition_teste_replace_all_float.max(axis=0)

# %%
nutrition_teste_replace_all_float.carbohydrate.nlargest(10)

# %%
nutrition_teste_replace_all_float.carbohydrate.nsmallest(10)

# %%
nutrition_teste_replace_all_float.nsmallest(n=5, columns='carbohydrate')
